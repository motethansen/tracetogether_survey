# %% [markdown]
# # Singapore Tracetogether survey data

# %%
# setup pandas and read the csv file

import pandas as pd

df_import = pd.read_excel('citizens_survey.xlsx',sheet_name='Form Responses 1')
df_import.head()
#define new header titles

df_header= {'Timestamp':'Timestamp',            
            'What is your age group':'age',
            'What is your gender?':'gender',
            'Employment status?':'employment',
            'What is your education level?':'education',
            'How many times did you test positive for COVID-19 during the pandemic?':'covid',
            'If you had COVID, how did the fact that you became ill impact your job?':'job_impact',
            'How many vaccinations did you receive?':'vaccinations',
            'How would you rank the government\'s public support during Covid (1 to 5 = very satisfied) [Finance (Support)]':'rank_financial_support',
            'How would you rank the government\'s public support during Covid (1 to 5 = very satisfied) [medical(vaccines)]':'rank_medical_vaccines',
            'How would you rank the government\'s public support during Covid (1  to 5 = very satisfied) [Public safety (social distancing)]':'rank_social_distance',
            'How effective did you find the lockdown in Singapore? (rank 1 Least to 5 Most)':'lockdown_effectiveness',
            'How would you rate the usability of the Tracetogether app?':'UX_Tracetogether',
            'How frequently did you use the TraceTogether app or Token to check into venues in Singapore?':'TT_frequency',
            'Did the TraceTogether app help you to maintain social distancing during the pandemic? ':'TT_help_socialdistance',
            'Did the TraceTogether app help reduce the spread of COVID-19?':'TT_reduce_spread',
            'Did the government provide enough information about the TraceTogether app and its benefits?':'gov_info_benefit',
            'Did the TraceTogether app enhance your sense of participation and engagement in the fight against COVID-19?':'sense_participation',
            'Did the TraceTogether app help you to feel more connected with other citizens during the pandemic?':'connected_community',
            'Did the TraceTogether app help you to feel more connected with the government during the pandemic?':'connected_gov',
            'Do you think the TraceTogether app contributed to a safer environment for citizens during the pandemic?':'TT_safer_environment',
            'Do you think the government should invest in more smart city technologies like the TraceTogether app in the future?':'more_gov_invest_sc_tech',
            'Should the government involve citizens more in developing and implementing smart city technologies in the future?':'gov_involve_citizens',
            'What factors motivate you to participate in smart city projects? [Ranking form 1 Least - 5 Most] [Citizens\' participation]':'factor_citizens_participation',
            'What factors motivate you to participate in smart city projects? [Ranking form 1 Least - 5 Most] [Public-private partnership]':'factor_PPP',
            'What factors motivate you to participate in smart city projects? [Ranking form 1 Least - 5 Most] [Improved lifestyle]':'factor_improved_livestyle',
            'What factors motivate you to participate in smart city projects? [Ranking form 1 Least - 5 Most] [Better healthcare]':'factor_better_healthcare',
            'What factors motivate you to participate in smart city projects? [Ranking form 1 Least - 5 Most] [Improved public transport]':'factor_improved_public_transport',
            'What factors motivate you to participate in smart city projects? [Ranking form 1 Least - 5 Most] [Better education opportunities]':'factor_better_education',
            'What factors motivate you to participate in smart city projects? [Ranking form 1 Least - 5 Most] [More job availability]':'factor_more_jobs',
            'What factors motivate you to participate in smart city projects? [Ranking form 1 Least - 5 Most] [Other]':'factor_other',
            'If you selected Other, can you describe here?':'factor_other_txt',
            'Some cities have direct reporting or claim service for citizens. Other have social media channels where citizens can share opinions participation to be offered in your city?':'suggest_citizens_participation_txt',
            'What are the most effective ways to involve citizens in developing smart city projects? [rank 1 Least - 5 Most] [Survey]':'involvement_survey',
            'What are the most effective ways to involve citizens in developing smart city projects? [rank 1 Least - 5 Most] [City living labs]':'involvement_city_labs',
            'What are the most effective ways to involve citizens in developing smart city projects? [rank 1 Least - 5 Most] [Interviews]':'involvement_interviews',
            'What are the most effective ways to involve citizens in developing smart city projects? [rank 1 Least - 5 Most] [feedback and report solutions]':'involvement_feedback',
            'What are the most effective ways to involve citizens in developing smart city projects? [rank 1 Least - 5 Most] [inclusion with incentives]':'involvement_incentives',
            'What are the most effective ways to involve citizens in developing smart city projects? [rank 1 Least - 5 Most] [others]':'involvement_other',
            'How important is the government to involve citizens in developing smart city projects? [1 Least - 5 Most]':'importance_of_citizens_involve',
            'How would you rate the effectiveness of the government in involving citizens in developing smart city projects? [1 Least - 5 Most]':'effectiveness_citizens_involvement',
            'What factors influence citizens\' willingness to participate in smart city projects? [enter] ':'citizens_willingness_to_participate_txt',
            'How are you communicating or giving feedback to the local government?':'communication_channel_to_gov',
            'How satisfied are you with the responses from the local government, from your feedback or inquiries? [1 Least - 5 Most]':'response_satisfaction_from_gov',
            'What recommendations do you have for improving citizens\' participation in smart city projects in Singapore? [enter] ':'citizens_recommendations'
}


from typing import Iterable

def get_all_values(d):
    if isinstance(d, dict):
        for v in d.values():
            yield from get_all_values(v)
    elif isinstance(d, Iterable) and not isinstance(d, str): # or list, set, ... only
        for v in d:
            yield from get_all_values(v)
    else:
        yield d 
        
nheaderlist = []

nheaderlist=list(get_all_values(df_header))
print(nheaderlist)
df_import.columns= nheaderlist
#show all columns:
pd.set_option('display.max_columns', None)
df_import.head()
# Out:
# ['Timestamp', 'age', 'gender', 'employment', 'education', 'covid', 'job_impact', 'vaccinations', 'rank_financial_support', 'rank_medical_vaccines', 'rank_social_distance', 'lockdown_effectiveness', 'UX_Tracetogether', 'TT_frequency', 'TT_help_socialdistance', 'TT_reduce_spread', 'gov_info_benefit', 'sense_participation', 'connected_community', 'connected_gov', 'TT_safer_environment', 'more_gov_invest_sc_tech', 'gov_involve_citizens', 'factor_citizens_participation', 'factor_PPP', 'factor_improved_livestyle', 'factor_better_healthcare', 'factor_improved_public_transport', 'factor_better_education', 'factor_more_jobs', 'factor_other', 'factor_other_txt', 'suggest_citizens_participation_txt', 'involvement_survey', 'involvement_city_labs', 'involvement_interviews', 'involvement_feedback', 'involvement_incentives', 'involvement_other', 'importance_of_citizens_involve', 'effectiveness_citizens_involvement', 'citizens_willingness_to_participate_txt', 'communication_channel_to_gov', 'respons
# ...

# %%
df_import['index'] = df_import.index
df_import
# Out:
#                   Timestamp    age  gender                        employment  \
# 0   2023-03-09 20:33:13.281  45-54  Female  Out of work and looking for work
# 1   2023-03-09 20:50:20.797  45-54    Male                Employed full time
# 2   2023-03-11 11:39:33.838  35-44    Male                Employed full time
# 3   2023-03-18 19:18:17.917  45-54    Male                Employed full time
# 4   2023-03-18 19:20:36.586  55-64    Male                     Self-employed
# ..                      ...    ...     ...                               ...
# 143 2023-06-07 14:51:35.244  18-24  Female                Employed full time
# 144 2023-06-09 03:45:16.407  45-54    Male                Employed full time
# 145 2023-06-11 21:46:14.544  55-64    Male                     Self-employed
# 146 2023-06-13 13:20:33.146  25-34  Female                Employed full time
# 147 2023-07-04 22:55:18.267  25-34  Female                Employed full time
#
# ...

# %%
# fix data for job impact

job_impact= {
    '(1) lost job':1,
    '(2) Reduced work':2,
    '(3) More work':3,
    '(4) No impact':4
}
# fix for ranks
rank_gov_support= {
    '1 Not at all satisfied':1,
    '1 Not applicable':0,
    '2 Not satisfied':2,
    2:2,
    3:3,
    4:4,
    'Very satisfied':5,
    '5 Very satisfied':5
}
# fix for involvement
effective_citizens_involvement = {
    '1 Least':1,
    '2':2,
    '3':3,
    '4':4,
    '5 Most':5
}

factors = {
    '5 Most':5,
    4:4,
    3:3,
    2:2,
    '1 Least':1
}

df_import["job_impact"]=df_import["job_impact"].map(job_impact)
df_import["rank_financial_support"]=df_import["rank_financial_support"].map(rank_gov_support)
df_import["rank_medical_vaccines"]=df_import["rank_medical_vaccines"].map(rank_gov_support)
df_import["rank_social_distance"]=df_import["rank_social_distance"].map(rank_gov_support)
df_import["factor_citizens_participation"]=df_import["factor_citizens_participation"].map(factors)
df_import["factor_PPP"]=df_import["factor_PPP"].map(factors)
df_import["factor_improved_livestyle"]=df_import["factor_improved_livestyle"].map(factors)
df_import["factor_better_healthcare"]=df_import["factor_better_healthcare"].map(factors)
df_import["factor_improved_public_transport"]=df_import["factor_improved_public_transport"].map(factors)
df_import["factor_better_education"]=df_import["factor_better_education"].map(factors)
df_import["factor_more_jobs"]=df_import["factor_more_jobs"].map(factors)
df_import["factor_other"]=df_import["factor_other"].map(factors)
df_import["involvement_survey"]=df_import["involvement_survey"].map(factors)
df_import["involvement_city_labs"]=df_import["involvement_city_labs"].map(factors)
df_import["involvement_interviews"]=df_import["involvement_interviews"].map(factors)
df_import["involvement_feedback"]=df_import["involvement_feedback"].map(factors)
df_import["involvement_incentives"]=df_import["involvement_incentives"].map(factors)
df_import["involvement_other"]=df_import["involvement_other"].map(factors)

df_import
# Out:
#                   Timestamp    age  gender                        employment  \
# 0   2023-03-09 20:33:13.281  45-54  Female  Out of work and looking for work
# 1   2023-03-09 20:50:20.797  45-54    Male                Employed full time
# 2   2023-03-11 11:39:33.838  35-44    Male                Employed full time
# 3   2023-03-18 19:18:17.917  45-54    Male                Employed full time
# 4   2023-03-18 19:20:36.586  55-64    Male                     Self-employed
# ..                      ...    ...     ...                               ...
# 143 2023-06-07 14:51:35.244  18-24  Female                Employed full time
# 144 2023-06-09 03:45:16.407  45-54    Male                Employed full time
# 145 2023-06-11 21:46:14.544  55-64    Male                     Self-employed
# 146 2023-06-13 13:20:33.146  25-34  Female                Employed full time
# 147 2023-07-04 22:55:18.267  25-34  Female                Employed full time
#
# ...

# %%
df_TT_usage = df_import[['age','TT_frequency','UX_Tracetogether']]
gr_cnt = df_TT_usage.groupby(['age','TT_frequency'])['TT_frequency'].count()
gr_cnt
# Out:
# age    TT_frequency
# 18-24  Never                      1
#        every day                  7
#        once a month               3
#        twice a month              1
# 25-34  every day                 12
#        more than twice a week    11
# 35-44  Never                      1
#        every day                 16
#        more than twice a week     8
#        twice a month              4
# 45-54  every day                 37
#        more than twice a week    19
#        twice a month              4
# 55-64  Never                      1
#        every day                  9
#        more than twice a week     5
#        once a month               3
#        twice a month              2
# 65-74  every day                  2
#        more than twice a week     1
#        twice a month              1
# Name: TT_frequency, dtype: int64

# %%
#rank and factor
df_rank_factor = df_import[['rank_financial_support','rank_medical_vaccines','rank_social_distance','lockdown_effectiveness','UX_Tracetogether',
                           'factor_citizens_participation','factor_PPP','factor_improved_livestyle','factor_better_healthcare','factor_improved_public_transport',
                           'factor_better_education','factor_more_jobs','involvement_survey','involvement_city_labs','involvement_interviews','involvement_feedback',
                            'involvement_incentives','importance_of_citizens_involve','effectiveness_citizens_involvement']]
df_rank_factor.corr()
# Out:
#                                     rank_financial_support  \
# rank_financial_support                            1.000000
# rank_medical_vaccines                             0.501013
# rank_social_distance                              0.427289
# lockdown_effectiveness                            0.212480
# UX_Tracetogether                                  0.044002
# factor_citizens_participation                     0.210165
# factor_PPP                                        0.189809
# factor_improved_livestyle                         0.269632
# factor_better_healthcare                          0.295605
# factor_improved_public_transport                  0.266669
# factor_better_education                           0.184322
# factor_more_jobs                                  0.241677
# involvement_survey                                0.113282
# involvement_city_labs                             0.074490
# involvement_interviews                            0.194945
# ...

# %%
#stat
df_rank_factor.describe()
# Out:
#        rank_financial_support  rank_medical_vaccines  rank_social_distance  \
# count              148.000000             148.000000            148.000000
# mean                 2.567568               3.972973              3.750000
# std                  1.807626               1.309026              1.277087
# min                  0.000000               0.000000              0.000000
# 25%                  0.000000               3.000000              3.000000
# 50%                  3.000000               5.000000              4.000000
# 75%                  4.000000               5.000000              5.000000
# max                  5.000000               5.000000              5.000000
#
#        lockdown_effectiveness  UX_Tracetogether  \
# count              148.000000        148.000000
# mean                 3.952703          4.067568
# std                  1.150773          1.054063
# min                  1.000000          1.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

dims = (11, 8)
fig = plt.subplots(figsize=dims)
correlation_full_health = df_rank_factor.corr().round(3)

axis_corr = sns.heatmap(
correlation_full_health,
vmin=-1, vmax=1, center=0,
cmap=sns.diverging_palette(2, 600, n=25),
square=True, annot=False
)

plt.show()

# %%
# Correlation between different variables
#
import numpy as np
corr = df_rank_factor.corr().round(2)
#
# Set up the matplotlib plot configuration
#
f, ax = plt.subplots(figsize=(12, 10))
#
# Generate a mask for upper traingle
#
mask = np.triu(np.ones_like(corr, dtype=bool))
#
# Configure a custom diverging colormap
#
cmap = sns.diverging_palette(230, 20, as_cmap=True)
#
# Draw the heatmap
#
sns.heatmap(corr, annot=True, mask = mask, cmap=cmap)
# Out:
# <Axes: >

# %%
#rank and factor
df_involve_factor = df_import[['factor_citizens_participation','factor_PPP','factor_improved_livestyle','factor_better_healthcare','factor_improved_public_transport',
                           'factor_better_education','factor_more_jobs','involvement_survey','involvement_city_labs','involvement_interviews','involvement_feedback',
                            'involvement_incentives','importance_of_citizens_involve','effectiveness_citizens_involvement']]
df_involve_factor.corr()
# Out:
#                                     factor_citizens_participation  factor_PPP  \
# factor_citizens_participation                            1.000000    0.610064
# factor_PPP                                               0.610064    1.000000
# factor_improved_livestyle                                0.630831    0.461521
# factor_better_healthcare                                 0.655256    0.472437
# factor_improved_public_transport                         0.641379    0.490764
# factor_better_education                                  0.670100    0.511149
# factor_more_jobs                                         0.660220    0.548924
# involvement_survey                                       0.366358    0.285971
# involvement_city_labs                                    0.313489    0.377657
# involvement_interviews                                   0.329255    0.387726
# involvement_feedback                                     0.385994    0.408589
# ...

# %%
# Correlation between different variables
#
import numpy as np
corr = df_involve_factor.corr().round(2)
#
# Set up the matplotlib plot configuration
#
f, ax = plt.subplots(figsize=(12, 10))
#
# Generate a mask for upper traingle
#
mask = np.triu(np.ones_like(corr, dtype=bool))
#
# Configure a custom diverging colormap
#
cmap = sns.diverging_palette(230, 20, as_cmap=True)
#
# Draw the heatmap
#
heatmap_survey = sns.heatmap(corr, annot=True, mask = mask, cmap=cmap)
plt.yticks(rotation = 0, fontsize=9)
plt.xticks(rotation = 90, fontsize=9)
plt.title("Correlation of survey data", fontsize=16, fontweight="bold")
fig = heatmap_survey.get_figure()
fig.savefig("corr_heatmap.png", dpi=300, bbox_inches='tight') 
#plt.savefig("corr_heatmap.png")

# %%
cit_wil_part_text_df= df_import[['citizens_willingness_to_participate_txt']]
cit_wil_part_text_df
# Out:
#                citizens_willingness_to_participate_txt
# 0                                          Incentives
# 1           Lower price or easier life than status quo
# 2                Educating the public on the benefits
# 3                                                    .
# 4                                              no idea
# ..                                                 ...
# 143  Time - people often have other priorities and ...
# 144                                           Privacy
# 145  The fact that they (the citizens) are most lik...
# 146                              Monetary compensation
# 147                        Educating them on the pros
#
# [148 rows x 1 columns]

# %%
cit_wil_part_text_df = cit_wil_part_text_df[cit_wil_part_text_df["citizens_willingness_to_participate_txt"].str.contains("na") == False]
cit_wil_part_text_df = cit_wil_part_text_df[cit_wil_part_text_df["citizens_willingness_to_participate_txt"].str.contains("Na") == False]
cit_wil_part_text_df = cit_wil_part_text_df[cit_wil_part_text_df["citizens_willingness_to_participate_txt"].str.contains("Nil") == False]
cit_wil_part_text_df = cit_wil_part_text_df[cit_wil_part_text_df["citizens_willingness_to_participate_txt"].str.contains("nan") == False]
cit_wil_part_text_df = cit_wil_part_text_df[cit_wil_part_text_df["citizens_willingness_to_participate_txt"].str.contains("X") == False]
cit_wil_part_text_df = cit_wil_part_text_df[cit_wil_part_text_df["citizens_willingness_to_participate_txt"].str.contains("None") == False]

# %%
#wordcloud
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator


# Start with one Text column:
text_df = cit_wil_part_text_df[['citizens_willingness_to_participate_txt']]
#text_df
text=""

for key, value in cit_wil_part_text_df['citizens_willingness_to_participate_txt'].items():
    #print(key, value)
    #print("key: ", key)
    #print("value: ", value)
    text = text+" "+str(value)+" "

print(text)    

# Create and generate a word cloud image:
wordcloud = WordCloud(width = 300, height = 300,max_font_size=50, max_words=100, background_color="white", colormap = "ocean_r").generate(text)

# Display the generated image:
plt.figure(figsize=[15,10])
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
wordcloud.to_file("cit_willingness_to_participate.png")
# Out:
#  Incentives   Lower price or easier life than status quo  Educating the public on the benefits   .  no idea  Not sure if this question is about motivation, if so. then time, efforts and incentive are the factors   No comments   Most important to be involved  Anonymity   By understanding its usefulness.  Willingness to hear feedback   Incentives
# ...

# %%
#extract from citizens recommendation to participation

# Start with one Text column:
cit_text_df = df_import[['citizens_recommendations']]
#text_df

cit_text_df = cit_text_df[cit_text_df["citizens_recommendations"].str.contains("na") == False]
cit_text_df = cit_text_df[cit_text_df["citizens_recommendations"].str.contains("Na") == False]
cit_text_df = cit_text_df[cit_text_df["citizens_recommendations"].str.contains("Nil") == False]
cit_text_df = cit_text_df[cit_text_df["citizens_recommendations"].str.contains("nan") == False]
cit_text_df = cit_text_df[cit_text_df["citizens_recommendations"].str.contains("X") == False]
cit_text_df = cit_text_df[cit_text_df["citizens_recommendations"].str.contains("None") == False]

cit_text=""

for key, value in cit_text_df['citizens_recommendations'].items():
    #print(key, value)
    #print("key: ", key)
    #print("value: ", value)
    cit_text = cit_text+" "+str(value)+" "

print(cit_text)    

# Create and generate a word cloud image:
wordcloud = WordCloud(width = 300, height = 300,max_font_size=50, max_words=100, background_color="white", colormap = "ocean").generate(cit_text)

# Display the generated image:
plt.figure(figsize=[15,10])
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
wordcloud.to_file("cit_textwordcloud.png")
# Out:
#  Roadshows to create awareness  Handling citizens data is dismal level with no respect to individual citizens privacy rights. Include foreigners in to the process to take it to next level   Run campaign about the benefits of participating in smart city projects   .  no opinion  There should be more awareness created  No comments   Help and unite one another  Politicians should stay connected to people on the ground.  More information on future city living  Incentives  Give more incentives for participation   Involvement, involvement, involvement of every citizen.   User experience survey and interview   feedback  Make it worth their time  More freedom to express opposing views  Keep up with the modern technology  allow PRs to vote and allow all non citizens to take part  Encourage more social programs within the neighborhoods.   Be more open about the technology used  Take care all residents regardless which area they are staying. Not just focus on hdb area.   Involve all residents  
# ...

# %%
# get data from citizens usage of tracetogether

# column: UX_Tracetogether	TT_frequency	TT_help_socialdistance	TT_reduce_spread	gov_info_benefit	sense_participation	connected_community	connected_gov	TT_safer_environment	more_gov_invest_sc_tech	gov_involve_citizens

df_TT_stat = df_import[['UX_Tracetogether','TT_frequency','TT_help_socialdistance',
                        'TT_reduce_spread','gov_info_benefit','sense_participation',
                        'connected_community','connected_gov','TT_safer_environment',
                        'more_gov_invest_sc_tech','gov_involve_citizens']]
df_TT_stat
# Out:
#      UX_Tracetogether            TT_frequency TT_help_socialdistance  \
# 0                   3               every day                  Maybe
# 1                   3               every day                     No
# 2                   5               every day                  Maybe
# 3                   5               every day                  Maybe
# 4                   4            once a month                     No
# ..                ...                     ...                    ...
# 143                 4               every day                     No
# 144                 4               every day                    Yes
# 145                 4  more than twice a week                  Maybe
# 146                 1               every day                  Maybe
# 147                 5               every day                  Maybe
#
#     TT_reduce_spread gov_info_benefit sense_participation connected_community  \
# ...

# %%
# change string to numbers

freq = {'Never':1,
        'once a month':2,
        'twice a month':3,
        'more than twice a week':4,
        'every day':5
       }

yesno = { 'Yes':3, 'Maybe':2, 'No':1}

opinion = { 'Strongly disagree':1,
           'Disagree':2,
           'Neutral':3,
           'Agree':4,
           'Strongly agree':5

}

#update records in the dataframe
df_TT_stat["TT_frequency"]=df_TT_stat["TT_frequency"].map(freq)
df_TT_stat["TT_help_socialdistance"]=df_TT_stat["TT_help_socialdistance"].map(yesno)
df_TT_stat["TT_reduce_spread"]=df_TT_stat["TT_reduce_spread"].map(yesno)
df_TT_stat["gov_info_benefit"]=df_TT_stat["gov_info_benefit"].map(yesno)
df_TT_stat["sense_participation"]=df_TT_stat["sense_participation"].map(yesno)
df_TT_stat["connected_community"]=df_TT_stat["connected_community"].map(yesno)
df_TT_stat["connected_gov"]=df_TT_stat["connected_gov"].map(yesno)
df_TT_stat["TT_safer_environment"]=df_TT_stat["TT_safer_environment"].map(yesno)
df_TT_stat["more_gov_invest_sc_tech"]=df_TT_stat["more_gov_invest_sc_tech"].map(yesno)
df_TT_stat["gov_involve_citizens"]=df_TT_stat["gov_involve_citizens"].map(opinion)
df_TT_stat
# Out:
# /var/folders/r9/s9f9f5cj77l7qzjyd8t03b1h0000gn/T/ipykernel_6279/2220777702.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TT_stat["TT_frequency"]=df_TT_stat["TT_frequency"].map(freq)
# /var/folders/r9/s9f9f5cj77l7qzjyd8t03b1h0000gn/T/ipykernel_6279/2220777702.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_TT_stat["TT_help_socialdistance"]=df_TT_stat["TT_help_socialdistance"].map(yesno)
# ...

# %%
#Check stat

df_TT_stat.describe()
# Out:
#        UX_Tracetogether  TT_frequency  TT_help_socialdistance  \
# count        148.000000    148.000000              148.000000
# mean           4.067568      4.337838                2.195946
# std            1.054063      0.937169                0.796752
# min            1.000000      1.000000                1.000000
# 25%            4.000000      4.000000                2.000000
# 50%            4.000000      5.000000                2.000000
# 75%            5.000000      5.000000                3.000000
# max            5.000000      5.000000                3.000000
#
#        TT_reduce_spread  gov_info_benefit  sense_participation  \
# count        148.000000        148.000000           148.000000
# mean           2.344595          2.493243             2.466216
# std            0.725745          0.760385             0.777363
# min            1.000000          1.000000             1.000000
# 25%            2.000000          2.000000             2.000000
# ...

# %%
TT_freq_usage = df_TT_stat.groupby(['TT_frequency'])['TT_frequency'].count()
TT_freq_usage
# Out:
# TT_frequency
# 1     3
# 2     6
# 3    12
# 4    44
# 5    83
# Name: TT_frequency, dtype: int64

# %%
plt.figure(figsize = (9, 6))
plt.bar(x = ['Never','once a month',
            'twice a month',
            'more than twice a week',
            'every day'] , height=TT_freq_usage,
        #height =TT_freq_usage["TT_frequency"], 
        color = "midnightblue")
plt.xticks( fontsize = 13, rotation=50)
plt.yticks( fontsize = 13)
plt.title("Frequency usage of TraceTogether", fontsize = 16, fontweight = "bold")
plt.ylabel("Frequency", fontsize = 13 )
plt.tight_layout()
#plt.savefig("frequency_usage.png")
plt.show()

# %%
df_TT_stat.groupby(['TT_help_socialdistance'])['TT_help_socialdistance'].count()
# Out:
# TT_help_socialdistance
# 1    35
# 2    49
# 3    64
# Name: TT_help_socialdistance, dtype: int64

# %%
df_TT_stat.groupby(['TT_reduce_spread'])['TT_reduce_spread'].count()
# Out:
# TT_reduce_spread
# 1    22
# 2    53
# 3    73
# Name: TT_reduce_spread, dtype: int64

# %%
df_TT_stat.groupby(['connected_community'])['connected_community'].count()
# Out:
# connected_community
# 1    66
# 2    26
# 3    56
# Name: connected_community, dtype: int64

# %%
df_TT_stat.groupby(['more_gov_invest_sc_tech'])['more_gov_invest_sc_tech'].count()
# Out:
# more_gov_invest_sc_tech
# 1    16
# 2    34
# 3    98
# Name: more_gov_invest_sc_tech, dtype: int64

# %%
citizens_involve=df_import.groupby(['importance_of_citizens_involve'])['importance_of_citizens_involve'].count()
citizens_involve
# Out:
# importance_of_citizens_involve
# 1     2
# 2     1
# 3    12
# 4    35
# 5    98
# Name: importance_of_citizens_involve, dtype: int64

# %%
plt.figure(figsize = (9, 6))
plt.bar(x = ['Strongly Disagree','Disagree',
           'Neutral',
           'Agree',
           'Strongly agree'] , height=citizens_involve,
        color = "midnightblue")
plt.xticks( fontsize = 13, rotation=50)
plt.yticks( fontsize = 13)
plt.title("Citizens involvement in Smart City projects", fontsize = 16, fontweight = "bold")
plt.ylabel("Opinion", fontsize = 13 )
plt.tight_layout()
plt.savefig("citizens_involved_in_SC_projects.png")
plt.show()

# %% [markdown]
# # Sentiment analysis
# ## Looking at three different entries by the respondents. Then compare the response for one, and avg of all

# %%
df_sentiment_text = df_import[['index','importance_of_citizens_involve','suggest_citizens_participation_txt','citizens_willingness_to_participate_txt','citizens_recommendations']]
df_sentiment_text
# Out:
#      index  importance_of_citizens_involve  \
# 0        0                               5
# 1        1                               4
# 2        2                               5
# 3        3                               3
# 4        4                               5
# ..     ...                             ...
# 143    143                               4
# 144    144                               5
# 145    145                               5
# 146    146                               5
# 147    147                               4
#
#                     suggest_citizens_participation_txt  \
# 0                                             Not sure
# 1         Incentives like cashback or free healthcare
# 2    This question is not clear. If it gives some e...
# 3                          Thru social media channels
# 4                                           No opinion
# ..                                                 ...
# ...

# %%
#replace Nan and Nil and Na with empty string

df_sentiment_text= df_sentiment_text.replace(np.nan, '', regex=True)
df_sentiment_text= df_sentiment_text.replace('Nil', '', regex=True)
df_sentiment_text= df_sentiment_text.replace('Nil', '', regex=True)
df_sentiment_text= df_sentiment_text.replace('no idea', '', regex=True)
df_sentiment_text= df_sentiment_text.replace('No comments', '', regex=True)
df_sentiment_text= df_sentiment_text.replace('None', '', regex=True)
df_sentiment_text= df_sentiment_text.replace('No opinion', '', regex=True)
df_sentiment_text= df_sentiment_text.replace('no opinion', '', regex=True)
df_sentiment_text
# Out:
#      index  importance_of_citizens_involve  \
# 0        0                               5
# 1        1                               4
# 2        2                               5
# 3        3                               3
# 4        4                               5
# ..     ...                             ...
# 143    143                               4
# 144    144                               5
# 145    145                               5
# 146    146                               5
# 147    147                               4
#
#                     suggest_citizens_participation_txt  \
# 0                                             Not sure
# 1         Incentives like cashback or free healthcare
# 2    This question is not clear. If it gives some e...
# 3                          Thru social media channels
# 4
# ..                                                 ...
# 143  Perhaps generate forums. So that those who are...
# ...

# %%
plt.style.use('ggplot')
import nltk

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/michaelhansen/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/michaelhansen/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/michaelhansen/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/michaelhansen/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %% [markdown]
# ## exploring using NLTK

# %%
def listToString(s):
 
    # initialize an empty string
    str1 = ""
 
    # traverse in the string
    for ele in s:
        str1 += ele
 
    # return string
    return str1


example = df_sentiment_text['suggest_citizens_participation_txt'][143]
print(example)
example2 = df_sentiment_text.iloc[143]
text_list = example2[['suggest_citizens_participation_txt','citizens_willingness_to_participate_txt','citizens_recommendations']]
listToString(text_list)
# Out:
# Perhaps generate forums. So that those who are active and want to participate can voice their opinion. While others who are within the area and are affected have access to the information and decisions made.
# 'Perhaps generate forums. So that those who are active and want to participate can voice their opinion. While others who are within the area and are affected have access to the information and decisions made.  Time - people often have other priorities and place that first such as work and family. Therefore if you were to incentivise them through monetary means, participation is often higher. Participants are often thinking "what do I get out of this?" It either has to be quick and simple or very engaging with some sort of reward '

# %%
tokens = nltk.word_tokenize(example)
tokens[:10]
# Out:
# ['Perhaps',
#  'generate',
#  'forums',
#  '.',
#  'So',
#  'that',
#  'those',
#  'who',
#  'are',
#  'active']

# %%
tagged = nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('Perhaps', 'RB'),
#  ('generate', 'VB'),
#  ('forums', 'NNS'),
#  ('.', '.'),
#  ('So', 'IN'),
#  ('that', 'IN'),
#  ('those', 'DT'),
#  ('who', 'WP'),
#  ('are', 'VBP'),
#  ('active', 'JJ')]

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   Perhaps/RB
#   generate/VB
#   forums/NNS
#   ./.
#   So/IN
#   that/IN
#   those/DT
#   who/WP
#   are/VBP
#   active/JJ
#   and/CC
#   want/VBP
#   to/TO
#   participate/VB
#   can/MD
#   voice/VB
#   their/PRP$
#   opinion/NN
#   ./.
#   While/IN
#   others/NNS
#   who/WP
#   are/VBP
#   within/IN
#   the/DT
#   area/NN
#   and/CC
#   are/VBP
#   affected/VBN
#   have/JJ
#   access/NN
#   to/TO
#   the/DT
#   information/NN
#   and/CC
#   decisions/NNS
#   made/VBN
#   ./.)

# %% [markdown]
# # Vader Sentiment scoring

# %%
#download vader lexicon
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/michaelhansen/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.043, 'neu': 0.851, 'pos': 0.106, 'compound': 0.34}

# %%
# Run the polarity score on the entire dataset
res = {}
for i, row in tqdm(df_sentiment_text.iterrows(), total=len(df_sentiment_text)):
    resultlist = df_sentiment_text.iloc[i]
    text = listToString(resultlist[['suggest_citizens_participation_txt','citizens_willingness_to_participate_txt','citizens_recommendations']])
    listToString(text_list)
    res[i] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/148 [00:00<?, ?it/s]

# %%
#get df with involve opinions
df_involve = df_sentiment_text[['index','importance_of_citizens_involve']]
df_involve = df_involve.set_index('index')
df_involve.head(3)
# Out:
#        importance_of_citizens_involve
# index
# 0                                   5
# 1                                   4
# 2                                   5

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'Id'})
vaders =pd.DataFrame(vaders).set_index('Id')
vaders = pd.merge(vaders, df_involve, left_index=True, right_index=True) #vaders.merge(df_involve, how='left')

# %%
# Now we have sentiment score and metadata
vaders.head()
# Out:
#       neg    neu    pos  compound  importance_of_citizens_involve
# Id
# 0   0.000  0.704  0.296    0.2732                               5
# 1   0.157  0.581  0.262    0.6808                               4
# 2   0.054  0.647  0.299    0.8694                               5
# 3   0.000  1.000  0.000    0.0000                               3
# 4   0.000  0.000  0.000    0.0000                               5

# %% [markdown]
# # plot VADER results

# %%
ax = sns.barplot(data=vaders, x='importance_of_citizens_involve', y='compound')
ax.set_title('Compund Score of respondents opinion to involve citizens')
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 3))
sns.barplot(data=vaders, x='importance_of_citizens_involve', y='pos', ax=axs[0])
sns.barplot(data=vaders, x='importance_of_citizens_involve', y='neu', ax=axs[1])
sns.barplot(data=vaders, x='importance_of_citizens_involve', y='neg', ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %% [markdown]
# # analyse using RoBERTA model

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# %%
# Run for Roberta Model
encoded_text = tokenizer(example, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores_dict = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
}
print(scores_dict)
